# %%
import pandas as pd

# %%
old = pd.read_csv("dataset/fed_speech_content_unquoted.csv")
new = pd.read_csv("dataset/new_fed_speech_content_unquoted.csv")

# %%
merged = pd.concat([old, new], axis=0)
merged.to_csv("dataset/fed_speech.csv", index=False)
